# %% [markdown]
# <a href="https://colab.research.google.com/github/SrinijaVaibhavi/ML-Homework-3/blob/main/Untitled4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install surprise
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import pandas as pd
import numpy as np
from surprise import KNNBasic,Reader, Dataset, SVD
from surprise.model_selection import KFold, cross_validate
from surprise import Dataset, BaselineOnly, Reader
from surprise import SVD, KNNBasic, KNNWithMeans
from surprise.model_selection import cross_validate
import matplotlib.pyplot as plt
import seaborn as sns
from plotly.offline import init_notebook_mode, plot, iplot
import plotly.graph_objs as go
from IPython.display import Image
init_notebook_mode(connected=True)
# %matplotlib inline
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.18.2.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
DataPath = "/content/ratings_small.csv"


reader = Reader(line_format="user item rating timestamp", sep=',', skip_lines=1)

data = Dataset.load_from_file(DataPath, reader=reader)

# %%
rd = pd.read_csv('/content/ratings_small.csv')
rd
# Out:
#         userId  movieId  rating   timestamp
# 0            1       31     2.5  1260759144
# 1            1     1029     3.0  1260759179
# 2            1     1061     3.0  1260759182
# 3            1     1129     2.0  1260759185
# 4            1     1172     4.0  1260759205
# ...        ...      ...     ...         ...
# 99999      671     6268     2.5  1065579370
# 100000     671     6269     4.0  1065149201
# 100001     671     6365     4.0  1070940363
# 100002     671     6385     2.5  1070979663
# 100003     671     6565     3.5  1074784724
#
# [100004 rows x 4 columns]

# %%
pmf_svd = SVD()
cv_pmf = cross_validate(pmf_svd, data, measures=['RMSE', 'MAE'], cv=5, verbose=True);
# Out:
# Evaluating RMSE, MAE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.8944  0.8920  0.9029  0.8920  0.8984  0.8959  0.0042
# MAE (testset)     0.6878  0.6883  0.6964  0.6851  0.6926  0.6900  0.0040
# Fit time          3.40    1.36    1.39    1.39    1.37    1.78    0.81
# Test time         0.20    0.35    0.15    0.28    0.15    0.23    0.08

# %%
def CrossValidate(algorithms, cv=5):
	means = {}
	for name in algorithms:
		output = cross_validate(algorithms[name], data, measures=['RMSE', 'MAE'], cv=5, verbose=False)
		result = pd.DataFrame.from_dict(output)
		means[name] = result.mean()
	bm = pd.DataFrame.from_dict(means, orient='index')
	bm.drop(columns=['fit_time', 'test_time'], inplace=True)
	return bm

# %%
algorithm_ub = {
	'PMF': SVD(biased=False),
	'UserBased': KNNBasic(sim_options={'user_based': True}),
}

bms = CrossValidate(algorithm_ub)
# Out:
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.

# %%
bms
# Out:
#            test_rmse  test_mae
# PMF         1.007611  0.778285
# UserBased   0.968018  0.743959

# %%
algorithm_ib = {
	'PMF': SVD(biased=False),
	'ItemBased': KNNBasic(sim_options={'user_based': False}),
}

bm1 = CrossValidate(algorithm_ib)
# Out:
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.

# %%
bm1
# Out:
#            test_rmse  test_mae
# PMF         1.009727  0.779171
# ItemBased   0.935087  0.720882

# %%
similarities = ['cosine', 'pearson', 'msd']

SmlrtsUserBased = {}
for sim in similarities:
	SmlrtsUserBased['User Based-' + sim.upper()] = KNNBasic(sim_options={'name': sim, 'user_based': True})

# %%
bmsSmlrtsUserBased = CrossValidate(SmlrtsUserBased)
# Out:
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# ...

# %%
bmsSmlrtsUserBased
# Out:
#                     test_rmse  test_mae
# User Based-COSINE    0.993614  0.767312
# User Based-PEARSON   0.999309  0.773830
# User Based-MSD       0.968505  0.744661

# %%
similarities = ['cosine', 'pearson', 'msd']

SmlrtsItemBased = {}
for sim in similarities:
	SmlrtsItemBased['Item Based' + sim.upper()] = KNNBasic(sim_options={'name': sim, 'user_based': False})

# %%
bmsSmlrtsItemBased = CrossValidate(SmlrtsItemBased)
# Out:
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# ...

# %%
bmsSmlrtsItemBased
# Out:
#                    test_rmse  test_mae
# Item BasedCOSINE    0.996257  0.775247
# Item BasedPEARSON   0.989098  0.767913
# Item BasedMSD       0.934042  0.720467

# %%
bmsSmlrtsUserBased.plot(subplots=True)
# Out:
# array([<Axes: >, <Axes: >], dtype=object)

# %%
similarities = ['cosine', 'msd', 'pearson']
measures = ['RMSE', 'MAE']
results = {
    'ubcf': dict(),
    'ibcf': dict()
}

for sim in similarities:
  usercf = KNNBasic(sim_options={'name': sim, 'user_based': True})
  itemcf = KNNBasic(sim_options={'name': sim, 'user_based': False})

  print(f"Computing {sim} for User Based CF")
  cross_validate_ubcf = cross_validate(usercf, data, measures, verbose=True, cv=5)

  print(f"Computing {sim} for Item Based CF")
  cross_validate_ibcf = cross_validate(itemcf, data, measures, verbose=True, cv=5)

  results['ubcf'][sim] = cross_validate_ubcf
  results['ibcf'][sim] = cross_validate_ibcf
# Out:
# Computing cosine for User Based CF
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Evaluating RMSE, MAE of algorithm KNNBasic on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9911  0.9942  0.9962  1.0004  0.9848  0.9933  0.0052
# MAE (testset)     0.7664  0.7671  0.7701  0.7727  0.7598  0.7672  0.0044
# Fit time          0.19    0.20    0.21    0.39    0.40    0.28    0.10
# Test time         1.63    1.80    2.14    3.53    2.07    2.23    0.67
# Computing cosine for Item Based CF
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# ...

# %%
ptdata = {
    'mae': {
      'cosine': [],
      'msd': [],
      'pearson': []
    },
    'rmse': {
      'cosine': [],
      'msd': [],
      'pearson': []
    }
}

for k, v in results.items():
  for key, result in results[k].items():
    ptdata['mae'][key].append(result['test_mae'].mean())
    ptdata['rmse'][key].append(result['test_rmse'].mean())

# %%
ptdata
# Out:
# {'mae': {'cosine': [0.7672192923634968, 0.7745153980059343],
#   'msd': [0.743079084149079, 0.7204224150390848],
#   'pearson': [0.7729324974963879, 0.7682373068510159]},
#  'rmse': {'cosine': [0.9933433269770265, 0.9949111873654548],
#   'msd': [0.9666589663399716, 0.9345654385960284],
#   'pearson': [0.9984831449131658, 0.9894059416343743]}}

# %%
labels = ['User based Collaborative Filtering', 'Item based Collaborative Filtering']

x = np.arange(len(labels))
width = 0.1

plt.bar(x-0.1, ptdata['mae']['cosine'], width, color='blue')
plt.bar(x, ptdata['mae']['msd'], width, color='red')
plt.bar(x+0.1, ptdata['mae']['pearson'], width, color='green')

plt.xticks(x, labels)
plt.ylabel("MAE")
plt.yticks()
plt.legend(["Cosine", "MSD", "Pearson"])
plt.tight_layout()

plt.show()

# %%
labels = ['User based Collaborative Filtering', 'Item based Collaborative Filtering']

x = np.arange(len(labels))
width = 0.1
plt.bar(x-0.1, ptdata['rmse']['cosine'], width, color='blue')
plt.bar(x, ptdata['rmse']['msd'], width, color='red')
plt.bar(x+0.1, ptdata['rmse']['pearson'], width, color='green')

plt.xticks(x, labels)
plt.ylabel("RMSE")
plt.yticks()
plt.legend(["Cosine", "MSD", "Pearson"])
plt.tight_layout()

plt.show()

# %%
knnrange = range(1,30)

algorithms = {}
for i in knnrange:
	algorithms['KNN-User-' + str(i)] = KNNBasic(k=i, sim_options={'user_based': True})
bmsUb = CrossValidate(algorithms)
# Out:
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# ...

# %%
knnrange = range(1,30)

algorithms = {}
for i in knnrange:
	algorithms['KNN-User-' + str(i)] = KNNBasic(k=i, sim_options={'item_based': True})
bmsib = CrossValidate(algorithms)
# Out:
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# ...

# %%
X_LABEL = 'k'
Y_LABEL = 'RMSE'
TARGET_VAR = 'test_rmse'

plt.figure(figsize=(12,6))
plt.plot(knnrange, bmsUb[TARGET_VAR], label = "User-Based Collaborative Filtering")
plt.plot(knnrange, bmsib[TARGET_VAR], label = "Item-Based Collaborative Filtering")
plt.xlabel(X_LABEL, fontsize=12)
plt.ylabel(Y_LABEL, fontsize=12)
plt.title(Y_LABEL + ' vs. ' + X_LABEL)
plt.legend(loc='best')
plt.grid(ls='dotted')

plt.show()

# %%
X_LABEL = 'k'
Y_LABEL = 'RMSE'
TARGET_VAR = 'test_rmse'

plt.figure(figsize=(10,4))
plt.plot(knnrange, bmsib[TARGET_VAR], label = "Item-Based Collaborative Filtering")
plt.xlabel(X_LABEL, fontsize=12)
plt.ylabel(Y_LABEL, fontsize=12)
plt.title(Y_LABEL + ' vs. ' + X_LABEL)
plt.legend(loc='best')
plt.grid(ls='dotted')

plt.show()

# %%
X_LABEL = 'k'
Y_LABEL = 'RMSE'
TARGET_VAR = 'test_rmse'

plt.figure(figsize=(10,4))
plt.plot(knnrange, bmsUb[TARGET_VAR], label = "User-Based Collaborative Filtering")
plt.xlabel(X_LABEL, fontsize=12)
plt.ylabel(Y_LABEL, fontsize=12)
plt.title(Y_LABEL + ' vs. ' + X_LABEL)
plt.legend(loc='best')
plt.grid(ls='dotted')

plt.show()

# %%
X_LABEL = 'k'
Y_LABEL = 'MAE'
TARGET_VAR = 'test_mae'

plt.figure(figsize=(10,4))
plt.plot(knnrange, bmsUb[TARGET_VAR], label = "User-Based Collaborative Filtering")
plt.plot(knnrange, bmsib[TARGET_VAR], label = "Item-Based Collaborative Filtering")
plt.xlabel(X_LABEL, fontsize=12)
plt.ylabel(Y_LABEL, fontsize=12)
plt.title(Y_LABEL + ' vs. ' + X_LABEL)
plt.legend(loc='best')
plt.grid(ls='dotted')

plt.show()

# %%
X_LABEL = 'k'
Y_LABEL = 'MAE'
TARGET_VAR = 'test_mae'

plt.figure(figsize=(10,4))
plt.plot(knnrange, bmsUb[TARGET_VAR], label = "User-Based Collaborative Filtering")
plt.xlabel(X_LABEL, fontsize=12)
plt.ylabel(Y_LABEL, fontsize=12)
plt.title(Y_LABEL + ' vs. ' + X_LABEL)
plt.legend(loc='best')
plt.grid(ls='dotted')

plt.show()

# %%
X_LABEL = 'k'
Y_LABEL = 'MAE'
TARGET_VAR = 'test_mae'

plt.figure(figsize=(10,4))
plt.plot(knnrange, bmsib[TARGET_VAR], label = "Item-Based Collaborative Filtering")
plt.xlabel(X_LABEL, fontsize=12)
plt.ylabel(Y_LABEL, fontsize=12)
plt.title(Y_LABEL + ' vs. ' + X_LABEL)
plt.legend(loc='best')
plt.grid(ls='dotted')

plt.show()

# %%
best = {
	'User RMSE': (bmsUb['test_rmse'].idxmin(), bmsUb['test_rmse'].min()),
	'User MAE': (bmsUb['test_mae'].idxmin(), bmsUb['test_mae'].min()),
	'Item RMSE': (bmsib['test_rmse'].idxmin(), bmsib['test_rmse'].min()),
	'Item MAE': (bmsib['test_mae'].idxmin(), bmsib['test_mae'].min())
}

pd.DataFrame.from_dict(best, orient='index', columns=['Best K', 'Error Measure'])
# Out:
#                 Best K  Error Measure
# User RMSE  KNN-User-14       0.959940
# User MAE   KNN-User-14       0.734692
# Item RMSE  KNN-User-17       0.961512
# Item MAE   KNN-User-11       0.736114

# %%
best = {
    'User RMSE': (bmsUb['test_rmse'].idxmin(), bmsUb['test_rmse'].min()),
    'Item RMSE': (bmsib['test_rmse'].idxmin(), bmsib['test_rmse'].min()),
}

# %%
pd.DataFrame.from_dict(best, orient='index', columns=['Best K', 'RMSE'])
# Out:
#                 Best K      RMSE
# User RMSE  KNN-User-14  0.959940
# Item RMSE  KNN-User-17  0.961512
